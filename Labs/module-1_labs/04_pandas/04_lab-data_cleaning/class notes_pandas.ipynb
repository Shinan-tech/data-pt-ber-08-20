# %%
import pandas as pd

# %%
df = pd.read_csv("vehicles_messy.csv")
# Out:
# C:\Users\april\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE    ...     mfrCode  c240Dscr  charge240b  \
# 0       0.0     0.0    0.0    ...         NaN       NaN         0.0
# 1       0.0     0.0    0.0    ...         NaN       NaN         0.0
# 2       0.0     0.0    0.0    ...         NaN       NaN         0.0
# 3       0.0     0.0    0.0    ...         NaN       NaN         0.0
# 4       0.0     0.0    0.0    ...         NaN       NaN         0.0
#
#    c240bDscr                     createdOn                    modifiedOn  \
# ...

# %%
df.isnull().sum()
# Out:
# barrels08              0
# barrelsA08             0
# charge120              0
# charge240              0
# city08                 0
# city08U                0
# cityA08                0
# cityA08U               0
# cityCD                 0
# cityE                  0
# cityUF                 0
# co2                    0
# co2A                   0
# co2TailpipeAGpm        0
# co2TailpipeGpm         0
# comb08                 0
# comb08U                0
# combA08                0
# combA08U               0
# combE                  0
# combinedCD             0
# combinedUF             0
# cylinders            123
# displ                120
# drive               1189
# engId                  0
# eng_dscr           15403
# feScore                0
# fuelCost08             0
# fuelCostA08            0
#                    ...
# rangeCity              0
# rangeCityA             0
# rangeHwy               0
# rangeHwyA              0
# trany                 11
# UCity                  0
# ...

# %%
df.isnull().sum() / len(df)
# Out:
# barrels08          0.000000
# barrelsA08         0.000000
# charge120          0.000000
# charge240          0.000000
# city08             0.000000
# city08U            0.000000
# cityA08            0.000000
# cityA08U           0.000000
# cityCD             0.000000
# cityE              0.000000
# cityUF             0.000000
# co2                0.000000
# co2A               0.000000
# co2TailpipeAGpm    0.000000
# co2TailpipeGpm     0.000000
# comb08             0.000000
# comb08U            0.000000
# combA08            0.000000
# combA08U           0.000000
# combE              0.000000
# combinedCD         0.000000
# combinedUF         0.000000
# cylinders          0.003250
# displ              0.003171
# drive              0.031419
# engId              0.000000
# eng_dscr           0.407024
# feScore            0.000000
# fuelCost08         0.000000
# fuelCostA08        0.000000
#                      ...
# rangeCity          0.000000
# rangeCityA         0.000000
# ...

# %%
# df = df.drop([["evMoter", "mfrCode"]], axis = 1)

# %%
# df.isnull() -> the whole df
# pd.df.isnull()--> check row columns

# %%
null_cols = df.isnull().sum()
null_cols[null_cols > 10000]
# Out:
# eng_dscr      15403
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
df.count()
# Out:
# barrels08          37843
# barrelsA08         37843
# charge120          37843
# charge240          37843
# city08             37843
# city08U            37843
# cityA08            37843
# cityA08U           37843
# cityCD             37843
# cityE              37843
# cityUF             37843
# co2                37843
# co2A               37843
# co2TailpipeAGpm    37843
# co2TailpipeGpm     37843
# comb08             37843
# comb08U            37843
# combA08            37843
# combA08U           37843
# combE              37843
# combinedCD         37843
# combinedUF         37843
# cylinders          37720
# displ              37723
# drive              36654
# engId              37843
# eng_dscr           22440
# feScore            37843
# fuelCost08         37843
# fuelCostA08        37843
#                    ...
# rangeCity          37843
# rangeCityA         37843
# rangeHwy           37843
# rangeHwyA          37843
# trany              37832
# UCity              37843
# ...

# %%
null_cols[null_cols == 0]
# Out:
# barrels08          0
# barrelsA08         0
# charge120          0
# charge240          0
# city08             0
# city08U            0
# cityA08            0
# cityA08U           0
# cityCD             0
# cityE              0
# cityUF             0
# co2                0
# co2A               0
# co2TailpipeAGpm    0
# co2TailpipeGpm     0
# comb08             0
# comb08U            0
# combA08            0
# combA08U           0
# combE              0
# combinedCD         0
# combinedUF         0
# engId              0
# feScore            0
# fuelCost08         0
# fuelCostA08        0
# fuelType           0
# fuelType1          0
# ghgScore           0
# ghgScoreA          0
#                   ..
# highwayUF          0
# hlv                0
# hpv                0
# id                 0
# lv2                0
# lv4                0
# make               0
# model              0
# mpgData            0
# phevBlended        0
# pv2                0
# pv4                0
# ...

# %%
sum(df["cylinders"].isnull())
# Out:
# 123

# %%
df["trans_dscr"].isnull().sum()
# Out:
# 22796

# %%
df["cylinders"] = df["cylinders"].fillna(0)
sum(df["cylinders"].isnull())
# Out:
# 0

# %%
null_cols_10000 = list(null_cols[null_cols > 10000].index)
print(null_cols_10000)
# df.drop(null_cols_10000, axis =1)
# Out:
# ['eng_dscr', 'guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA', 'evMotor', 'mfrCode', 'c240Dscr', 'c240bDscr', 'startStop']

# %%
set(df["trany"])
# Out:
# {'Auto (AV)',
#  'Auto (AV-S6)',
#  'Auto (AV-S8)',
#  'Auto(A1)',
#  'Auto(AM-S6)',
#  'Auto(AM-S7)',
#  'Auto(AM-S8)',
#  'Auto(AM-S9)',
#  'Auto(AM5)',
#  'Auto(AM6)',
#  'Auto(AM7)',
#  'Auto(AM8)',
#  'Auto(AV-S6)',
#  'Auto(AV-S7)',
#  'Auto(AV-S8)',
#  'Auto(L3)',
#  'Auto(L4)',
#  'Automatic (A1)',
#  'Automatic (A6)',
#  'Automatic (AM5)',
#  'Automatic (AM6)',
#  'Automatic (AV)',
#  'Automatic (AV-S6)',
#  'Automatic (S4)',
#  'Automatic (S5)',
#  'Automatic (S6)',
#  'Automatic (S7)',
#  'Automatic (S8)',
#  'Automatic (S9)',
#  'Automatic (variable gear ratios)',
#  'Automatic 3-spd',
#  'Automatic 4-spd',
#  'Automatic 5-spd',
#  'Automatic 6-spd',
#  'Automatic 6spd',
#  'Automatic 7-spd',
#  'Automatic 8-spd',
#  'Automatic 9-spd',
#  'Manual 3-spd',
#  'Manual 4-spd',
#  'Manual 4-spd Doubled',
#  'Manual 5 spd',
#  'Manual 5-spd',
#  'Manual 6-spd',
#  'Manual 7-spd',
#  'Manual(M7)',
#  nan}

# %%
# df["trany"] = df["trany"].str.replace("-", "")
df["trany"].apply(lambda x: x.replace("-", ""))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-9f4bb92343b9> in <module>
#       1 # df["trany"] = df["trany"].str.replace("-", "")
# ----> 2 df["trany"].apply(lambda x: x.replace("-", ""))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-30-9f4bb92343b9> in <lambda>(x)
#       1 # df["trany"] = df["trany"].str.replace("-", "")
# ----> 2 df["trany"].apply(lambda x: x.replace("-", ""))
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
df["trany"] = df["trany"].str.replace("-", "").str.replace("Automatic", "Auto").str.replace(" ", "").str.replace("(", "").str(replace(")", ""))
set(df["trany"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-036ec688dfe9> in <module>
# ----> 1 df["trany"] = df["trany"].str.replace("-", "").str.replace("Automatic", "Auto").str.replace(" ", "").str.replace("(", "").str(replace(")", ""))
#       2 set(df["trany"])
#
# NameError: name 'replace' is not defined

# %%
# dropping duplicates comparing the whole raw
# df.drop_duplicates()
# df[["year", "cylinders", "trany"]].drop_duplicates()
df.drop_duplicates(["year", "cylinders", "trany"])
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# 5      14.982273         0.0        0.0        0.0      21      0.0        0
# 9      13.184400         0.0        0.0        0.0      23      0.0        0
# 18     17.347895         0.0        0.0        0.0      17      0.0        0
# 19     17.347895         0.0        0.0        0.0      17      0.0        0
# 20     20.600625         0.0        0.0        0.0      14      0.0        0
# 22     25.354615         0.0        0.0        0.0      11      0.0        0
# 24     17.347895         0.0        0.0        0.0      17      0.0        0
# ...

# %%
# pd.merge(a,b, left_on =, right_on =)
# a.merge(b, on=..., how =....)
