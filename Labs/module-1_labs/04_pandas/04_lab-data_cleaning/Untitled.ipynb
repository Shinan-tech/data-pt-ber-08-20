# %%
import pandas as pd
import numpy as np

# %%
# '../notes/vehicles.csv' '../vehicles.csv'
df = pd.read_csv("vehicles.csv")
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
df.drop(["Fuel Cost/Year"], axis = 1)
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
# the dataframe did not change 
df.rename(columns = {"Make":"Manufacture"}, inplace = True)
df.head()
# df = df.rename(columns = {"Make":"Manufacture"})
# Out:
#         Manufacture                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.drop(["Year", "Vehicle Class"], axis = 1)
# Out:
#                         Make                Model  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD                  2.5
# 1                 AM General     FJ8c Post Office                  4.2
# 2                 AM General  Post Office DJ5 2WD                  2.5
# 3                 AM General  Post Office DJ8 2WD                  4.2
# 4           ASC Incorporated                  GNX                  3.8
# 5                      Acura          2.2CL/3.0CL                  2.2
# 6                      Acura          2.2CL/3.0CL                  2.2
# 7                      Acura          2.2CL/3.0CL                  3.0
# 8                      Acura          2.3CL/3.0CL                  2.3
# 9                      Acura          2.3CL/3.0CL                  2.3
# 10                     Acura          2.3CL/3.0CL                  3.0
# 11                     Acura          2.3CL/3.0CL                  2.3
# ...

# %%
# del df["Year"]

# %%
df.rename(columns = {"Make":"Manufacture", "(Engine Displacement)":"Displacement"}, inplace = True)
df.head()
df["Manufacture"].head()
# Out:
# 0          AM General
# 1          AM General
# 2          AM General
# 3          AM General
# 4    ASC Incorporated
# Name: Manufacture, dtype: object

# %%
# select * from df where "Manufacture" = "Ford"
# temporary table df[df["Manufacture"] == "Ford"]

df_ford = df[df["Manufacture"] == "Ford"]
df_ford.head()
# Out:
#       Manufacture         Model  Year  Displacement  Cylinders  \
# 11440        Ford  Aerostar Van  1986           2.3        4.0
# 11441        Ford  Aerostar Van  1986           2.3        4.0
# 11442        Ford  Aerostar Van  1986           2.8        6.0
# 11443        Ford  Aerostar Van  1986           2.8        6.0
# 11444        Ford  Aerostar Van  1986           3.0        6.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11442  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11443     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11444     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11440          17.347895        18           22            19
# 11441          13.733750        23           26            24
# ...

# %%
# put () of each condition
df_ford_1986 = df[(df["Manufacture"] == "Ford") & (df["Year"] == 1986)]
df_ford_1986.head()
# Out:
#       Manufacture         Model  Year  Displacement  Cylinders  \
# 11440        Ford  Aerostar Van  1986           2.3        4.0
# 11441        Ford  Aerostar Van  1986           2.3        4.0
# 11442        Ford  Aerostar Van  1986           2.8        6.0
# 11443        Ford  Aerostar Van  1986           2.8        6.0
# 11444        Ford  Aerostar Van  1986           3.0        6.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11442  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11443     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11444     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11440          17.347895        18           22            19
# 11441          13.733750        23           26            24
# ...

# %%
df.describe()
# Out:
#               Year  Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000  35952.000000  35952.000000       35952.000000
# mean    2000.71640      3.338493      5.765076          17.609056
# std       10.08529      1.359395      1.755268           4.467283
# min     1984.00000      0.600000      2.000000           0.060000
# 25%     1991.00000      2.200000      4.000000          14.699423
# 50%     2001.00000      3.000000      6.000000          17.347895
# 75%     2010.00000      4.300000      6.000000          20.600625
# max     2017.00000      8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# ...

# %%
df["Hello"] = "Hello"
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
# new column created if only give df["Age"] = 2020 - df["Year"] --> don't see anything meaning it does something in the backgroud and changed the table
df["Age"] = 2020 - df["Year"]
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df["y2020"] = df["Year"] + df["Age"]
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.sum()
# Out:
# Make                       AM GeneralAM GeneralAM GeneralAM GeneralASC In...
# Model                      DJ Po Vehicle 2WDFJ8c Post OfficePost Office D...
# Year                                                                71929756
# Engine Displacement                                                   120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdAutomatic 3-spdA...
# Drivetrain                 2-Wheel Drive2-Wheel DriveRear-Wheel DriveRear...
# Vehicle Class              Special Purpose Vehicle 2WDSpecial Purpose Veh...
# Fuel Type                  RegularRegularRegularRegularPremiumRegularRegu...
# Fuel Barrels/Year                                                     633081
# City MPG                                                              634414
# Highway MPG                                                           858557
# ...

# %%
df.sum(axis = 1)
# Out:
# 0        4534.653529
# 1        5292.170000
# 2        4716.538125
# 3        5293.170000
# 4        5173.838125
# 5        3990.136818
# 6        3861.225417
# 7        4180.830500
# 8        3991.236818
# 9        3862.325417
# 10       4180.830500
# 11       3993.236818
# 12       3863.325417
# 13       4181.830500
# 14       4524.330500
# 15       4525.330500
# 16       4698.284737
# 17       4526.330500
# 18       4699.284737
# 19       4526.330500
# 20       4700.284737
# 21       4535.030500
# 22       4465.086190
# 23       4536.030500
# 24       4466.086190
# 25       4531.030500
# 26       4534.030500
# 27       4535.030500
# 28       4465.086190
# 29       4466.086190
#             ...
# 35922    6580.773636
# 35923    6580.773636
# 35924    3726.585000
# 35925    3851.325417
# 35926    3917.022174
# 35927    3789.964400
# 35928    3725.585000
# 35929    3727.585000
# 35930    3788.964400
# 35931    3785.764400
# 35932    3480.016944
# 35933    3481.016944
# ...

# %%
df["Year"].sum()
# np.sum["Year"]--> in this simple, we don't need np
# Out:
# 71929756

# %%
df[["Year", "Cylinders"]].sum()
# Out:
# Year         71929756.0
# Cylinders      207266.0
# dtype: float64

# %%
columns_to_compute = ["Year","City MPG"]
df[columns_to_compute].sum()
# Out:
# Year        71929756
# City MPG      634414
# dtype: int64

# %%
df.sort_values?

# %%
# the augument oder does not matter
df.sort_values(by = "Year")
df.sort_values(by = "Year", inplace = True)
df.head()
# Out:
#              Make                 Model  Year  Engine Displacement  Cylinders  \
# 0      AM General     DJ Po Vehicle 2WD  1984                  2.5        4.0
# 16337         GMC  T15 (S15) Pickup 4WD  1984                  2.8        6.0
# 16336         GMC  T15 (S15) Pickup 4WD  1984                  2.8        6.0
# 5636    Chevrolet  El Camino Pickup 2WD  1984                  3.8        6.0
# 5637    Chevrolet  El Camino Pickup 2WD  1984                  3.8        6.0
#
#           Transmission                  Drivetrain  \
# 0      Automatic 3-spd               2-Wheel Drive
# 16337     Manual 4-spd  4-Wheel or All-Wheel Drive
# 16336     Manual 5-spd  4-Wheel or All-Wheel Drive
# 5636   Automatic 3-spd               2-Wheel Drive
# 5637   Automatic 4-spd               2-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# ...

# %%
df.sort_values(by = ["Year", "City MPG"])
# Out:
#                                      Make                         Model  Year  \
# 9068                                Dodge                B350 Wagon 2WD  1984
# 10916                               Dodge          W100/W150 Pickup 4WD  1984
# 11936                                Ford            E250 Econoline 2WD  1984
# 11807                                Ford           E150 Club Wagon 2WD  1984
# 10974                               Dodge               W250 Pickup 4WD  1984
# 30164  S and S Coach Company  E.p. Dutton            Funeral Coach  2WD  1984
# 9716                                Dodge   D250 Pickup Cab Chassis 2WD  1984
# 8909                                Dodge           B150/B250 Wagon 2WD  1984
# 8705                                Dodge    AW100/AW150 Ramcharger 4WD  1984
# 12825                                Ford               F150 Pickup 4WD  1984
# 12605                                Ford               F150 Pickup 2WD  1984
# ...

# %%
df.nlargest(3, "Year")

# nsmallest
# df.nlargest(3, ["Year", "City MPG"])
# Out:
#             Make         Model  Year  Engine Displacement  Cylinders  \
# 7781   Chevrolet      Trax AWD  2017                  1.4        4.0
# 18759   Infiniti      QX70 RWD  2017                  3.7        6.0
# 3360       Buick  Envision FWD  2017                  2.5        4.0
#
#           Transmission         Drivetrain                    Vehicle Class  \
# 7781    Automatic (S6)    All-Wheel Drive  Small Sport Utility Vehicle 4WD
# 18759   Automatic (S7)   Rear-Wheel Drive  Small Sport Utility Vehicle 2WD
# 3360   Automatic 6-spd  Front-Wheel Drive  Small Sport Utility Vehicle 2WD
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 7781    Regular          12.207778        24           30            27
# 18759   Premium          17.347895        17           24            19
# 3360    Regular          13.184400        22           29            25
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# ...

# %%
# df["Make"].apply(str.upper)
df["Make"].apply(lambda x: x.upper())
# Out:
# 0           AM GENERAL
# 16337              GMC
# 16336              GMC
# 5636         CHEVROLET
# 5637         CHEVROLET
# 5638         CHEVROLET
# 5639         CHEVROLET
# 12606             FORD
# 5910         CHEVROLET
# 5640         CHEVROLET
# 16335              GMC
# 7485         CHEVROLET
# 16334              GMC
# 16332              GMC
# 10671            DODGE
# 10672            DODGE
# 5641         CHEVROLET
# 5642         CHEVROLET
# 12822             FORD
# 31664           SUBARU
# 20269             JEEP
# 12604             FORD
# 12603             FORD
# 16333              GMC
# 7486         CHEVROLET
# 7487         CHEVROLET
# 7488         CHEVROLET
# 10673            DODGE
# 31665           SUBARU
# 20275             JEEP
#              ...
# 2023               BMW
# 7215         CHEVROLET
# 1992               BMW
# 3138           BENTLEY
# 1994               BMW
# 1990               BMW
# 20590              KIA
# 3106           BENTLEY
# 20229             JEEP
# ...

# %%
# df["Make"].apply(str.replace("a", "b"))
df["Make"].apply(lambda x: x.replace("a", "b"))
# Out:
# 0           AM Generbl
# 16337              GMC
# 16336              GMC
# 5636         Chevrolet
# 5637         Chevrolet
# 5638         Chevrolet
# 5639         Chevrolet
# 12606             Ford
# 5910         Chevrolet
# 5640         Chevrolet
# 16335              GMC
# 7485         Chevrolet
# 16334              GMC
# 16332              GMC
# 10671            Dodge
# 10672            Dodge
# 5641         Chevrolet
# 5642         Chevrolet
# 12822             Ford
# 31664           Subbru
# 20269             Jeep
# 12604             Ford
# 12603             Ford
# 16333              GMC
# 7486         Chevrolet
# 7487         Chevrolet
# 7488         Chevrolet
# 10673            Dodge
# 31665           Subbru
# 20275             Jeep
#              ...
# 2023               BMW
# 7215         Chevrolet
# 1992               BMW
# 3138           Bentley
# 1994               BMW
# 1990               BMW
# 20590              Kib
# 3106           Bentley
# 20229             Jeep
# ...

# %%
# Aggregation
df.mean()
# Out:
# Year                       2000.716400
# Engine Displacement           3.338493
# Cylinders                     5.765076
# Fuel Barrels/Year            17.609056
# City MPG                     17.646139
# Highway MPG                  23.880646
# Combined MPG                 19.929322
# CO2 Emission Grams/Mile     475.316339
# Fuel Cost/Year             1892.598465
# dtype: float64

# %%
df.groupby?

# %%
df.groupby(["Fuel Type"]).mean()
# Out:
#                                     Year  Engine Displacement  Cylinders  \
# Fuel Type
# CNG                          2003.200000             3.963333   6.500000
# Diesel                       1994.929748             4.188913   6.225027
# Gasoline or E85              2010.501255             4.465188   6.974059
# Gasoline or natural gas      2004.000000             4.570000   6.800000
# Gasoline or propane          2002.500000             5.400000   8.000000
# Midgrade                     2014.148649             5.536486   7.864865
# Premium                      2005.575345             3.517075   6.365286
# Premium Gas or Electricity   2014.470588             1.764706   4.235294
# Premium and Electricity      2015.700000             2.345000   4.850000
# Premium or E85               2012.917355             3.680992   6.892562
# Regular                      1998.252597             3.164540   5.420952
# Regular Gas and Electricity  2014.625000             1.950000   4.000000
# ...

# %%
df.groupby(["Fuel Type", "Make"]).mean()
# Out:
#                                                                        Year  \
# Fuel Type                   Make
# CNG                         Chevrolet                           2004.400000
#                             Dodge                               1998.875000
#                             Ford                                2000.368421
#                             GMC                                 2004.500000
#                             Honda                               2006.500000
#                             Mobility Ventures LLC               2014.000000
#                             Toyota                              2000.000000
#                             VPG                                 2011.500000
# Diesel                      Audi                                2013.541667
#                             BMW                                 2012.000000
#                             Buick                               1984.909091
# ...

# %%
df.groupby(["Fuel Type"])["Cylinders", "City MPG"].mean()
# Out:
#                              Cylinders   City MPG
# Fuel Type
# CNG                           6.500000  15.966667
# Diesel                        6.225027  21.173436
# Gasoline or E85               6.974059  15.347280
# Gasoline or natural gas       6.800000  13.700000
# Gasoline or propane           8.000000  12.000000
# Midgrade                      7.864865  14.851351
# Premium                       6.365286  16.793166
# Premium Gas or Electricity    4.235294  30.705882
# Premium and Electricity       4.850000  24.900000
# Premium or E85                6.892562  17.305785
# Regular                       5.420952  17.970195
# Regular Gas and Electricity   4.000000  43.125000
# Regular Gas or Electricity    4.000000  43.000000

# %%
df.groupby(["Fuel Type"])["Cylinders", "City MPG"].agg(["mean", "max", "min"])
# Out:
#                             Cylinders              City MPG
#                                  mean   max  min       mean max min
# Fuel Type
# CNG                          6.500000   8.0  4.0  15.966667  27   8
# Diesel                       6.225027  10.0  4.0  21.173436  38  13
# Gasoline or E85              6.974059   8.0  4.0  15.347280  28  10
# Gasoline or natural gas      6.800000   8.0  4.0  13.700000  21  10
# Gasoline or propane          8.000000   8.0  8.0  12.000000  13  11
# Midgrade                     7.864865   8.0  6.0  14.851351  21  13
# Premium                      6.365286  16.0  2.0  16.793166  42   6
# Premium Gas or Electricity   4.235294   8.0  2.0  30.705882  41  20
# Premium and Electricity      4.850000   8.0  3.0  24.900000  37  16
# Premium or E85               6.892562  12.0  4.0  17.305785  24  11
# Regular                      5.420952  12.0  2.0  17.970195  58   7
# Regular Gas and Electricity  4.000000   4.0  4.0  43.125000  51  38
# ...

# %%
df.groupby(["Fuel Type"])["Cylinders", "City MPG"].agg(["mean", "max", "min"]).reset_index()
# Out:
#                       Fuel Type Cylinders              City MPG
#                                      mean   max  min       mean max min
# 0                           CNG  6.500000   8.0  4.0  15.966667  27   8
# 1                        Diesel  6.225027  10.0  4.0  21.173436  38  13
# 2               Gasoline or E85  6.974059   8.0  4.0  15.347280  28  10
# 3       Gasoline or natural gas  6.800000   8.0  4.0  13.700000  21  10
# 4           Gasoline or propane  8.000000   8.0  8.0  12.000000  13  11
# 5                      Midgrade  7.864865   8.0  6.0  14.851351  21  13
# 6                       Premium  6.365286  16.0  2.0  16.793166  42   6
# 7    Premium Gas or Electricity  4.235294   8.0  2.0  30.705882  41  20
# 8       Premium and Electricity  4.850000   8.0  3.0  24.900000  37  16
# 9                Premium or E85  6.892562  12.0  4.0  17.305785  24  11
# 10                      Regular  5.420952  12.0  2.0  17.970195  58   7
# ...
