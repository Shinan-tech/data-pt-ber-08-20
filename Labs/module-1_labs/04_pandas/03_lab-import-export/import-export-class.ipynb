# %% [markdown]
# ## Importing and exporting data in Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Subsetting and Filtering DataFrames

# %%
animals = pd.read_csv('sleepinmammals.csv')
animals
# Out:
#                    Species   BodyWt  BrainWt  NonDreaming  Dreaming  \
# 0          Africanelephant  6654.00  5712.00          NaN       NaN
# 1   Africangiantpouchedrat     1.00     6.60          6.3       2.0
# 2                ArcticFox  3385.00    44.50          NaN       NaN
# 3     Arcticgroundsquirrel     0.92     5.70          NaN       NaN
# 4            Asianelephant  2547.00  4603.00          2.1       1.8
# 5                   Baboon    10.55   179.50          9.1       0.7
# 6              Bigbrownbat    23.00     0.30         15.8       3.9
# 7           Braziliantapir   160.00   169.00          5.2       1.0
# 8                      Cat     3.30    25.60         10.9       3.6
# 9               Chimpanzee    52.16   440.00          8.3       1.4
# 10              Chinchilla   425.00     6.40         11.0       1.5
# 11                     Cow   465.00   423.00          3.2       0.7
# 12          Deserthedgehog     0.55     2.40          7.6       2.7
# ...

# %% [markdown]
# Inspecting the dataframe

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
# Species        62 non-null object
# BodyWt         62 non-null float64
# BrainWt        62 non-null float64
# NonDreaming    48 non-null float64
# Dreaming       50 non-null float64
# TotalSleep     58 non-null float64
# LifeSpan       58 non-null float64
# Gestation      58 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 4.0+ KB

# %% [markdown]
# Getting all the column names of the df

# %%
animals.columns
# Out:
# Index(['Species', 'BodyWt', 'BrainWt', 'NonDreaming', 'Dreaming', 'TotalSleep',
#        'LifeSpan', 'Gestation'],
#       dtype='object')

# %% [markdown]
# Selecting column Bodywt

# %%
animals['BodyWt']
# Out:
# 0     6654.00
# 1        1.00
# 2     3385.00
# 3        0.92
# 4     2547.00
#        ...
# 57       2.00
# 58     104.00
# 59       4.19
# 60       3.50
# 61       4.05
# Name: BodyWt, Length: 62, dtype: float64

# %% [markdown]
# Extracting row 11 - 20

# %%
animals[11:21]
# Out:
#                 Species  BodyWt  BrainWt  NonDreaming  Dreaming  TotalSleep  \
# 11                  Cow  465.00    423.0          3.2       0.7         3.9
# 12       Deserthedgehog    0.55      2.4          7.6       2.7        10.3
# 13               Donkey  187.10    419.0          NaN       NaN         3.1
# 14  EasternAmericanmole   75.00      1.2          6.3       2.1         8.4
# 15              Echidna    3.00     25.0          8.6       0.0         8.6
# 16     Europeanhedgehog  785.00      3.5          6.6       4.1        10.7
# 17               Galago    0.20      5.0          9.5       1.2        10.7
# 18                Genet    1.41     17.5          4.8       1.3         6.1
# 19       Giantarmadillo   60.00     81.0         12.0       6.1        18.1
# 20              Giraffe  529.00    680.0          NaN       0.3         NaN
#
#     LifeSpan  Gestation
# 11      30.0      281.0
# 12       NaN        NaN
# 13      40.0      365.0
# 14       3.5       42.0
# ...

# %% [markdown]
# Extracting rows 11 - 20 for the first 3 columns

# %%
animals.iloc[11:21, 0:3]
# Out:
#                 Species  BodyWt  BrainWt
# 11                  Cow  465.00    423.0
# 12       Deserthedgehog    0.55      2.4
# 13               Donkey  187.10    419.0
# 14  EasternAmericanmole   75.00      1.2
# 15              Echidna    3.00     25.0
# 16     Europeanhedgehog  785.00      3.5
# 17               Galago    0.20      5.0
# 18                Genet    1.41     17.5
# 19       Giantarmadillo   60.00     81.0
# 20              Giraffe  529.00    680.0

# %% [markdown]
# Extracting rows 11 - 20 for columns Species to Brainweight

# %%
animals.loc[11:20, 'BodyWt':'Dreaming']
# Out:
#     BodyWt  BrainWt  NonDreaming  Dreaming
# 11  465.00    423.0          3.2       0.7
# 12    0.55      2.4          7.6       2.7
# 13  187.10    419.0          NaN       NaN
# 14   75.00      1.2          6.3       2.1
# 15    3.00     25.0          8.6       0.0
# 16  785.00      3.5          6.6       4.1
# 17    0.20      5.0          9.5       1.2
# 18    1.41     17.5          4.8       1.3
# 19   60.00     81.0         12.0       6.1
# 20  529.00    680.0          NaN       0.3

# %% [markdown]
# Getting all the rows where BrainWt < 2

# %%
animals[animals['BrainWt'] < 10]
# Out:
#                     Species  BodyWt  BrainWt  NonDreaming  Dreaming  \
# 1    Africangiantpouchedrat    1.00     6.60          6.3       2.0
# 3      Arcticgroundsquirrel    0.92     5.70          NaN       NaN
# 6               Bigbrownbat   23.00     0.30         15.8       3.9
# 10               Chinchilla  425.00     6.40         11.0       1.5
# 12           Deserthedgehog    0.55     2.40          7.6       2.7
# 14      EasternAmericanmole   75.00     1.20          6.3       2.1
# 16         Europeanhedgehog  785.00     3.50          6.6       4.1
# 17                   Galago    0.20     5.00          9.5       1.2
# 22            Goldenhamster    0.12     1.00         11.0       3.4
# 26           Groundsquirrel  101.00     4.00         10.4       3.4
# 27                Guineapig    1.04     5.50          7.4       0.8
# 31  Lessershort-tailedshrew    5.00     0.14          7.7       1.4
# 32           Littlebrownbat    0.01     0.25         17.9       2.0
# ...

# %%
animals['BrainWt'] < 10
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
#       ...
# 57    False
# 58     True
# 59    False
# 60     True
# 61    False
# Name: BrainWt, Length: 62, dtype: bool

# %% [markdown]
# Getting the names of Species where BodyWt > 5 and BrainWt < 5
